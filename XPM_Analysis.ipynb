# %% [markdown]
# Getting data from github, use the RAW DATAFILE!!
#
# Tc:Ta:TcRise:TaRise:cat:an:offst:datime:IR:UV

# %%
#libraries needed to download from github
import pandas as pd
import requests
import io


def getData():
  #to download file from github, for different data, simply change the url -- RAW FILE!!
  columns = ['Tc', 'Ta', 'TcRise', 'TaRise', 'cat', 'an', 'offst', 'datime', 'IR', 'UV', 'E11', 'E12', 'E13']
  url = "https://raw.githubusercontent.com/shamondho/nEXOskyline/main/XPM_analysis/data/control8.txt"
  download = requests.get(url).content

  #now the downloaded content is being read, and being turned into a pandas dataframe

  df = pd.read_csv(url, header = None, names = columns)

  type(df)
  pd.set_option("display.max.columns", None)
  return df


getData()
# Out:
#        Tc    Ta  TcRise  TaRise        cat         an      offst  \
# 0    10.0  81.9     1.0     2.9   8.554580   8.724318  41.229859
# 1    10.0  81.9     1.0     2.9   7.841152   7.752292  42.952972
# 2    10.0  81.9     1.0     2.9  32.058562  30.211050  39.644468
# 3    10.0  81.9     1.0     2.9  32.467392  31.867325  43.526298
# 4    10.0  81.9     1.0     2.9  33.937485  32.826951  43.121104
# ..    ...   ...     ...     ...        ...        ...        ...
# 276  10.0  81.9     1.0     2.9  30.258154  31.172977  42.834409
# 277  10.0  81.9     1.0     2.9  29.572565  30.086902  42.857146
# 278  10.0  81.9     1.0     2.9  29.134760  29.867330  42.975755
# 279  10.0  81.9     1.0     2.9  29.230506  30.099974  43.143539
# 280  10.0  81.9     1.0     2.9  28.918987  29.588957  43.280575
#
#            datime          IR           UV        E11    E12    E13
# 0    3.991821e+09  465.390625   481.015625   5.643809  128.0   18.0
# 1    3.991821e+09  462.812500   468.593750   2.083298  128.0  131.0
# 2    3.991821e+09  374.062500  1195.156250  68.872418  128.0  114.0
# 3    3.991821e+09  385.468750  1223.515625   2.284192  128.0  132.0
# 4    3.991821e+09  399.531250  1256.718750   2.207485  128.0  131.0
# ..            ...         ...          ...        ...    ...    ...
# 276  3.992304e+09  418.671875  1328.828125   2.142635  128.0  132.0
# 277  3.992305e+09  409.687500  1289.609375   2.566119  128.0  132.0
# 278  3.992305e+09  432.656250  1351.406250   2.121161  128.0  132.0
# 279  3.992305e+09  427.109375  1355.156250   2.276803  128.0  137.0
# 280  3.992305e+09  429.062500  1356.328125   2.677639  128.0  132.0
#
# [281 rows x 13 columns]

# %%
# %matplotlib inline

getData()


histogram = df["UV"]

histogram.plot(kind="hist")


df.plot(x="cat", y="UV", kind="scatter")
